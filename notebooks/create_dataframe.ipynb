# %%
df_list = [
    {"Avversario" : "Parabiago",
    "Round" : 1,
    "Data" : "2024-10-13",
    "Score CUS Torino" : 22,
    "Score Avversario" : 28,
    "Home/Away" : "Away",
    "Mete CUS Torino" : 1,
    "Mete Avversario" : 3,
    "Placcaggi Tentati" : 158,
    "Placcaggi Non Avanzanti" : 119,
    "Placcaggi Mancati" : 12,
    "Placcaggi Avanzanti" : 7,
    "Placcaggi Cover" : 5,
    "Falli Offensivi" : 9,
    "Falli Difensivi" : 3,
    "Tempo Effettivo": "33:11",
    "Possesso CUS Torino": 48,
    "Territorio CUS Torino": 56,
    "Numero di Punti d'Incontro": 64,
    "Numero Portatori": 71,
    "Portatori Dominanti": 2,
    "Portatori Avanzanti": 24,
    "Portatori Non Avanzanti": 45,
    "Tackle Breaks": 3,
    "Numero Passaggi": 85,
    "Passaggi Positivi": 85,
    "Passaggi Negativi": 0,
    "Numero Offload": 3,
    "Offload Positivi": 0,
    "Offload Negativi": 3,
    "Difensori Battuti": 4,
    "Numero Kicks in Play": 13,
    "Kicks Positivo": 12,
    "Kicks Negativo": 1,
},
{"Avversario" : "Milano",
    "Round" : 2,
    "Data" : "2024-10-20",
    "Score CUS Torino" : 22,
    "Score Avversario" : 21,
    "Home/Away" : "Away",
    "Mete CUS Torino" : 3,
    "Mete Avversario" : 2,
    "Placcaggi Tentati" : 165,
    "Placcaggi Non Avanzanti" : 123,
    "Placcaggi Mancati" : 15,
    "Placcaggi Avanzanti" : 5,
    "Placcaggi Cover" : 4,
    "Falli Offensivi" : 1,
    "Falli Difensivi" : 12,
    "Tempo Effettivo": "33:26",
    "Possesso CUS Torino": 51,
    "Territorio CUS Torino": 51,
    "Numero di Punti d'Incontro": 64,
    "Numero Portatori": 77,
    "Portatori Dominanti": 1,
    "Portatori Avanzanti": 31,
    "Portatori Non Avanzanti": 45,
    "Tackle Breaks": 7,
    "Numero Passaggi": 105,
    "Passaggi Positivi": 100,
    "Passaggi Negativi": 5,
    "Numero Offload": 0,
    "Offload Positivi": 0,
    "Offload Negativi": 0,
    "Difensori Battuti": 12,
    "Numero Kicks in Play": 9,
    "Kicks Positivo": 9,
    "Kicks Negativo": 0,
},
{
    "Avversario": "Avezzano",
    "Round": 3,
    "Data": "2024-10-27",
    "Score CUS Torino": 28,
    "Score Avversario": 25,
    "Home/Away": "Away",
    "Mete CUS Torino": 3,
    "Mete Avversario": 1,
    "Placcaggi Tentati": 124,
    "Placcaggi Non Avanzanti": 63,
    "Placcaggi Mancati": 10,
    "Placcaggi Avanzanti": 21,
    "Placcaggi Cover": 10,
    "Falli Offensivi": 9,
    "Falli Difensivi": 8,
    "Tempo Effettivo": "32:33",
    "Possesso CUS Torino": 51,
    "Territorio CUS Torino": 49,
    "Numero di Punti d'Incontro": 73,
    "Numero Portatori": 83,
    "Portatori Dominanti": 0,
    "Portatori Avanzanti": 52,
    "Portatori Non Avanzanti": 31,
    "Tackle Breaks": 9,
    "Numero Passaggi": 126,
    "Passaggi Positivi": 121,
    "Passaggi Negativi": 5,
    "Numero Offload": 2,
    "Offload Positivi": 2,
    "Offload Negativi": 0,
    "Difensori Battuti": 13,
    "Numero Kicks in Play": 18,
    "Kicks Positivo": 13,
    "Kicks Negativo": 5,
},
{"Avversario" : "Biella",
    "Round" : 4,
    "Data" : "2024-11-03",
    "Score CUS Torino" : 34,
    "Score Avversario" : 34,
    "Home/Away" : "Away",
    "Mete CUS Torino" : 5,
    "Mete Avversario" : 4,
    "Placcaggi Tentati" : 55,
    "Placcaggi Non Avanzanti" : 31,
    "Placcaggi Mancati" : 4,
    "Placcaggi Avanzanti" : 6,
    "Placcaggi Cover" : 9,
    "Falli Offensivi" : 6,
    "Falli Difensivi" : 4,
    "Tempo Effettivo": "31:33",
    "Possesso CUS Torino": 64,
    "Territorio CUS Torino": 46,
    "Numero di Punti d'Incontro": 85,
    "Numero Portatori": 99,
    "Portatori Dominanti": 3,
    "Portatori Avanzanti": 47,
    "Portatori Non Avanzanti": 49,
    "Tackle Breaks": 6,
    "Numero Passaggi": 135,
    "Passaggi Positivi": 134,
    "Passaggi Negativi": 1,
    "Numero Offload": 2,
    "Offload Positivi": 2,
    "Offload Negativi": 0,
    "Difensori Battuti": 12,
    "Numero Kicks in Play": 19,
    "Kicks Positivo": 15,
    "Kicks Negativo": 4,
},
{"Avversario" : "Verona",
    "Round" : 5,
    "Data" : "2024-11-17",
    "Score CUS Torino" : 30,
    "Score Avversario" : 26,
    "Home/Away" : "Away",
    "Mete CUS Torino" : 3,
    "Mete Avversario" : 3,
    "Placcaggi Tentati" : 124,
    "Placcaggi Non Avanzanti" : 69,
    "Placcaggi Mancati" : 8,
    "Placcaggi Avanzanti" : 9,
    "Placcaggi Cover" : 20,
    "Falli Offensivi" : 2,
    "Falli Difensivi" : 8,
    "Tempo Effettivo": "33:16",
    "Possesso CUS Torino": 53,
    "Territorio CUS Torino": 50,
    "Numero di Punti d'Incontro": 67,
    "Numero Portatori": 85,
    "Portatori Dominanti": 2,
    "Portatori Avanzanti": 49,
    "Portatori Non Avanzanti": 34,
    "Tackle Breaks": 13,
    "Numero Passaggi": 119,
    "Passaggi Positivi": 115,
    "Passaggi Negativi": 4,
    "Numero Offload": 5,
    "Offload Positivi": 5,
    "Offload Negativi": 0,
    "Difensori Battuti": 16,
    "Numero Kicks in Play": 16,
    "Kicks Positivo": 10,
    "Kicks Negativo": 6,
},
{"Avversario" : "Capitolina",
    "Round" : 6,
    "Data" : "2024-12-01",
    "Score CUS Torino" : 24,
    "Score Avversario" : 25,
    "Home/Away" : "Home",
    "Mete CUS Torino" : 4,
    "Mete Avversario" : 3,
    "Placcaggi Tentati" : 186,
    "Placcaggi Non Avanzanti" : 117,
    "Placcaggi Mancati" : 23,
    "Placcaggi Avanzanti" : 7,
    "Placcaggi Cover" : 0,
    "Falli Offensivi" : 5,
    "Falli Difensivi" : 6,
    "Tempo Effettivo": "40:53",
    "Possesso CUS Torino": 40,
    "Territorio CUS Torino": 64,
    "Numero di Punti d'Incontro": 70,
    "Numero Portatori": 87,
    "Portatori Dominanti": 0,
    "Portatori Avanzanti": 42,
    "Portatori Non Avanzanti": 45,
    "Tackle Breaks": 10,
    "Numero Passaggi": 121,
    "Passaggi Positivi": 115,
    "Passaggi Negativi": 6,
    "Numero Offload": 2,
    "Offload Positivi": 1,
    "Offload Negativi": 1,
    "Difensori Battuti": 18,
    "Numero Kicks in Play": 12,
    "Kicks Positivo": 10,
    "Kicks Negativo": 2,
},
{"Avversario" : "Paese",
    "Round" : 7,
    "Data" : "2024-12-15",
    "Score CUS Torino" : 26,
    "Score Avversario" : 33,
    "Home/Away" : "Away",
    "Mete CUS Torino" : 3,
    "Mete Avversario" : 5,
    "Placcaggi Tentati" : 92,
    "Placcaggi Non Avanzanti" : 78,
    "Placcaggi Mancati" : 14,
    "Placcaggi Avanzanti" : 3,
    "Placcaggi Cover" : 3,
    "Falli Offensivi" : 4,
    "Falli Difensivi" : 3,
    "Tempo Effettivo": "30:50",
    "Possesso CUS Torino": 38,
    "Territorio CUS Torino": 61,
    "Numero di Punti d'Incontro": 42,
    "Numero Portatori": 51,
    "Portatori Dominanti": 2,
    "Portatori Avanzanti": 26,
    "Portatori Non Avanzanti": 23,
    "Tackle Breaks": 11,
    "Numero Passaggi": 79,
    "Passaggi Positivi": 77,
    "Passaggi Negativi": 2,
    "Numero Offload": 2,
    "Offload Positivi": 2,
    "Offload Negativi": 0,
    "Difensori Battuti": 17,
    "Numero Kicks in Play": 21,
    "Kicks Positivo": 17,
    "Kicks Negativo": 4,
},
{"Avversario" : "Cavalieri",
    "Round" : 8,
    "Data" : "2024-12-23",
    "Score CUS Torino" : 22,
    "Score Avversario" : 26,
    "Home/Away" : "Home",
    "Mete CUS Torino" : 3,
    "Mete Avversario" : 2,
    "Placcaggi Tentati" : 156,
    "Placcaggi Non Avanzanti" : 62,
    "Placcaggi Mancati" : 25,
    "Placcaggi Avanzanti" : 14,
    "Placcaggi Cover" : 21,
    "Falli Offensivi" : 6,
    "Falli Difensivi" : 6,
    "Tempo Effettivo": "39:02",
    "Possesso CUS Torino": 56,
    "Territorio CUS Torino": 51,
    "Numero di Punti d'Incontro": 103,
    "Numero Portatori": 120,
    "Portatori Dominanti": 5,
    "Portatori Avanzanti": 52,
    "Portatori Non Avanzanti": 63,
    "Tackle Breaks": 18,
    "Numero Passaggi": 156,
    "Passaggi Positivi": 150,
    "Passaggi Negativi": 6,
    "Numero Offload": 6,
    "Offload Positivi": 6,
    "Offload Negativi": 0,
    "Difensori Battuti": 33,
    "Numero Kicks in Play": 16,
    "Kicks Positivo": 11,
    "Kicks Negativo": 5,
},
{"Avversario" : "Petrarca",
    "Round" : 9,
    "Data" : "2025-01-19",
    "Score CUS Torino" : 28,
    "Score Avversario" : 30,
    "Home/Away" : "Away",
    "Mete CUS Torino" : 3,
    "Mete Avversario" : 4,
    "Placcaggi Tentati" : 130,
    "Placcaggi Non Avanzanti" : 65,
    "Placcaggi Mancati" : 11,
    "Placcaggi Avanzanti" : 4,
    "Placcaggi Cover" : 13,
    "Falli Offensivi" : 3,
    "Falli Difensivi" : 10,
    "Tempo Effettivo": "36:30",
    "Possesso CUS Torino": 58,
    "Territorio CUS Torino": 37,
    "Numero di Punti d'Incontro": 64,
    "Numero Portatori": 135,
    "Portatori Dominanti": 5,
    "Portatori Avanzanti": 55,
    "Portatori Non Avanzanti": 19,
    "Tackle Breaks": 14,
    "Numero Passaggi": 163,
    "Passaggi Positivi": 98,
    "Passaggi Negativi": 2,
    "Numero Offload": 6,
    "Offload Positivi": 1,
    "Offload Negativi": 5,
    "Difensori Battuti": 15,
    "Numero Kicks in Play": 18,
    "Kicks Positivo": 3,
    "Kicks Negativo": 15,
}
]

# %%
import pandas as pd
df = pd.DataFrame(df_list)
df.head()
# Out:
#   Avversario  Round        Data  Score CUS Torino  Score Avversario Home/Away  \
# 0  Parabiago      1  2024-10-13                22                28      Away
# 1     Milano      2  2024-10-20                22                21      Away
# 2   Avezzano      3  2024-10-27                28                25      Away
# 3     Biella      4  2024-11-03                34                34      Away
# 4     Verona      5  2024-11-17                30                26      Away
#
#    Mete CUS Torino  Mete Avversario  Placcaggi Tentati  \
# 0                1                3                158
# 1                3                2                165
# 2                3                1                124
# 3                5                4                 55
# 4                3                3                124
#
#    Placcaggi Non Avanzanti  ...  Numero Passaggi  Passaggi Positivi  \
# 0                      119  ...               85                 85
# ...

# %%
df.columns
# Out:
# Index(['Avversario', 'Round', 'Data', 'Score CUS Torino', 'Score Avversario',
#        'Home/Away', 'Mete CUS Torino', 'Mete Avversario', 'Placcaggi Tentati',
#        'Placcaggi Non Avanzanti', 'Placcaggi Mancati', 'Placcaggi Avanzanti',
#        'Placcaggi Cover', 'Falli Offensivi', 'Falli Difensivi',
#        'Tempo Effettivo', 'Possesso CUS Torino', 'Territorio CUS Torino',
#        'Numero di Punti d'Incontro', 'Numero Portatori', 'Portatori Dominanti',
#        'Portatori Avanzanti', 'Portatori Non Avanzanti', 'Tackle Breaks',
#        'Numero Passaggi', 'Passaggi Positivi', 'Passaggi Negativi',
#        'Numero Offload', 'Offload Positivi', 'Offload Negativi',
#        'Difensori Battuti', 'Numero Kicks in Play', 'Kicks Positivo',
#        'Kicks Negativo'],
#       dtype='object')

# %%
df['Risultato'] = df.apply(lambda x: 'Vittoria' if x['Score CUS Torino'] > x['Score Avversario'] else 'Pareggio' if x['Score CUS Torino'] == x['Score Avversario'] else 'Sconfitta', axis = 1)

# %% [markdown]
# df["Tempo Effettivo"] = pd.to_timedelta("00:" + df["Tempo Effettivo"])

# %%
df.to_csv('../rsc/data/season2425.csv', index = False, sep=';')

# %%
df["Tempo Effettivo"] = pd.to_timedelta("00:" + df["Tempo Effettivo"])

# %%
df["Tempo Effettivo"].dt.total_seconds() / 60
# Out:
# 0    33.183333
# 1    33.433333
# 2    32.550000
# 3    31.550000
# 4    33.266667
# 5    40.883333
# 6    30.833333
# 7    39.033333
# 8    36.500000
# Name: Tempo Effettivo, dtype: float64
